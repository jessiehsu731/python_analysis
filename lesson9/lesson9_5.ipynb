# %%
# !pip install jinja2
# Out:
# Collecting jinja2
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting MarkupSafe>=2.0 (from jinja2)
#   Downloading MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl (15 kB)
# Installing collected packages: MarkupSafe, jinja2
# Successfully installed MarkupSafe-3.0.2 jinja2-3.1.6

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

# %%
df = pd.DataFrame({
    "strings": ["Adam", "Mike"],
    "ints": [1, 3],
    "floats": [1.123, 1000.23]
})
df
# Out:
#   strings  ints    floats
# 0    Adam     1     1.123
# 1    Mike     3  1000.230

# %%
df.style\
.format(
    precision=2,
    thousands=',',
    decimal='.'
).format_index(axis=1,formatter=str.upper)\
.relabel_index(["row1","row2"], axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8191d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8191d_level0_col0" class="col_heading level0 col0" >STRINGS</th>
#       <th id="T_8191d_level0_col1" class="col_heading level0 col1" >INTS</th>
#       <th id="T_8191d_level0_col2" class="col_heading level0 col2" >FLOATS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8191d_level0_row0" class="row_heading level0 row0" >row1</th>
#       <td id="T_8191d_row0_col0" class="data row0 col0" >Adam</td>
#       <td id="T_8191d_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_8191d_row0_col2" class="data row0 col2" >1.12</td>
#     </tr>
#     <tr>
#       <th id="T_8191d_level0_row1" class="row_heading level0 row1" >row2</th>
#       <td id="T_8191d_row1_col0" class="data row1 col0" >Mike</td>
#       <td id="T_8191d_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_8191d_row1_col2" class="data row1 col2" >1,000.23</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd
import numpy as np

# 範例 DataFrame
data = {
    'A': [1234.5678, 9876.5432, 10000.00],
    'B': [0.1234, 0.5678, 0.9999],
    'C': ['蘋果', '香蕉', '櫻桃'],
    'D': pd.to_datetime(['2023-10-26', '2023-10-27', '2023-10-28']),
    'E': [np.nan, 1, 2]
}
df = pd.DataFrame(data)
df
# Out:
#             A       B   C          D    E
# 0   1234.5678  0.1234  蘋果 2023-10-26  NaN
# 1   9876.5432  0.5678  香蕉 2023-10-27  1.0
# 2  10000.0000  0.9999  櫻桃 2023-10-28  2.0

# %%
styled_df1 = df.style.format("{:.2F}", subset=['A','B'])
styled_df1
# Out:
# <style type="text/css">
# </style>
# <table id="T_ef77e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef77e_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_ef77e_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_ef77e_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_ef77e_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_ef77e_level0_col4" class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef77e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ef77e_row0_col0" class="data row0 col0" >1234.57</td>
#       <td id="T_ef77e_row0_col1" class="data row0 col1" >0.12</td>
#       <td id="T_ef77e_row0_col2" class="data row0 col2" >蘋果</td>
#       <td id="T_ef77e_row0_col3" class="data row0 col3" >2023-10-26 00:00:00</td>
#       <td id="T_ef77e_row0_col4" class="data row0 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ef77e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ef77e_row1_col0" class="data row1 col0" >9876.54</td>
#       <td id="T_ef77e_row1_col1" class="data row1 col1" >0.57</td>
#       <td id="T_ef77e_row1_col2" class="data row1 col2" >香蕉</td>
#       <td id="T_ef77e_row1_col3" class="data row1 col3" >2023-10-27 00:00:00</td>
#       <td id="T_ef77e_row1_col4" class="data row1 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ef77e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ef77e_row2_col0" class="data row2 col0" >10000.00</td>
#       <td id="T_ef77e_row2_col1" class="data row2 col1" >1.00</td>
#       <td id="T_ef77e_row2_col2" class="data row2 col2" >櫻桃</td>
#       <td id="T_ef77e_row2_col3" class="data row2 col3" >2023-10-28 00:00:00</td>
#       <td id="T_ef77e_row2_col4" class="data row2 col4" >2.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                        index=pd.date_range(start="2021-01-01", periods=10),
                        columns=["Tokyo", "Taipei"])

# %%
weather_df.style\
.set_caption("Weather Conditions")\
.background_gradient(axis=None, vmin=1, vmax=5, cmap='BuPu',subset=['Tokyo'])
# Out:
# <style type="text/css">
# #T_8ac1d_row0_col0 {
#   background-color: #bacfe4;
#   color: #000000;
# }
# #T_8ac1d_row1_col0 {
#   background-color: #cedfec;
#   color: #000000;
# }
# #T_8ac1d_row2_col0 {
#   background-color: #8c69b0;
#   color: #f1f1f1;
# }
# #T_8ac1d_row3_col0 {
#   background-color: #8c80bb;
#   color: #f1f1f1;
# }
# #T_8ac1d_row4_col0 {
#   background-color: #c1d4e7;
#   color: #000000;
# }
# #T_8ac1d_row5_col0 {
#   background-color: #a4c0dc;
#   color: #000000;
# }
# #T_8ac1d_row6_col0 {
#   background-color: #8c71b4;
#   color: #f1f1f1;
# }
# #T_8ac1d_row7_col0 {
#   background-color: #dce9f2;
#   color: #000000;
# }
# #T_8ac1d_row8_col0 {
#   background-color: #852d90;
#   color: #f1f1f1;
# }
# #T_8ac1d_row9_col0 {
#   background-color: #92a4cd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8ac1d">
#   <caption>Weather Conditions</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ac1d_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_8ac1d_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ac1d_level0_row0" class="row_heading level0 row0" >2021-01-01 00:00:00</th>
#       <td id="T_8ac1d_row0_col0" class="data row0 col0" >2.085809</td>
#       <td id="T_8ac1d_row0_col1" class="data row0 col1" >2.820472</td>
#     </tr>
#     <tr>
#       <th id="T_8ac1d_level0_row1" class="row_heading level0 row1" >2021-01-02 00:00:00</th>
#       <td id="T_8ac1d_row1_col0" class="data row1 col0" >1.769118</td>
#       <td id="T_8ac1d_row1_col1" class="data row1 col1" >1.840004</td>
#     </tr>
#     <tr>
#       <th id="T_8ac1d_level0_row2" class="row_heading level0 row2" >2021-01-03 00:00:00</th>
#       <td id="T_8ac1d_row2_col0" class="data row2 col0" >3.525815</td>
#       <td id="T_8ac1d_row2_col1" class="data row2 col1" >1.306452</td>
#     </tr>
#     <tr>
#       <th id="T_8ac1d_level0_row3" class="row_heading level0 row3" >2021-01-04 00:00:00</th>
#       <td id="T_8ac1d_row3_col0" class="data row3 col0" >3.252666</td>
#       <td id="T_8ac1d_row3_col1" class="data row3 col1" >2.569060</td>
#     </tr>
#     <tr>
#       <th id="T_8ac1d_level0_row4" class="row_heading level0 row4" >2021-01-05 00:00:00</th>
#       <td id="T_8ac1d_row4_col0" class="data row4 col0" >1.969672</td>
#       <td id="T_8ac1d_row4_col1" class="data row4 col1" >1.951241</td>
#     </tr>
#     <tr>
#       <th id="T_8ac1d_level0_row5" class="row_heading level0 row5" >2021-01-06 00:00:00</th>
#       <td id="T_8ac1d_row5_col0" class="data row5 col0" >2.418344</td>
#       <td id="T_8ac1d_row5_col1" class="data row5 col1" >1.499083</td>
#     </tr>
#     <tr>
#       <th id="T_8ac1d_level0_row6" class="row_heading level0 row6" >2021-01-07 00:00:00</th>
#       <td id="T_8ac1d_row6_col0" class="data row6 col0" >3.434692</td>
#       <td id="T_8ac1d_row6_col1" class="data row6 col1" >0.668541</td>
#     </tr>
#     <tr>
#       <th id="T_8ac1d_level0_row7" class="row_heading level0 row7" >2021-01-08 00:00:00</th>
#       <td id="T_8ac1d_row7_col0" class="data row7 col0" >1.565518</td>
#       <td id="T_8ac1d_row7_col1" class="data row7 col1" >2.644859</td>
#     </tr>
#     <tr>
#       <th id="T_8ac1d_level0_row8" class="row_heading level0 row8" >2021-01-09 00:00:00</th>
#       <td id="T_8ac1d_row8_col0" class="data row8 col0" >4.191100</td>
#       <td id="T_8ac1d_row8_col1" class="data row8 col1" >3.338349</td>
#     </tr>
#     <tr>
#       <th id="T_8ac1d_level0_row9" class="row_heading level0 row9" >2021-01-10 00:00:00</th>
#       <td id="T_8ac1d_row9_col0" class="data row9 col0" >2.822066</td>
#       <td id="T_8ac1d_row9_col1" class="data row9 col1" >4.751781</td>
#     </tr>
#   </tbody>
# </table>

# %%
def rain_condition(v):
    if v < 1.75:
        return "乾燥"
    elif v < 2.75:
        return "有雨"
    else:
        return "大雨"
    
def change_index(t):
    return t.strftime('%Y年%m月%d日')

weather_df.style\
.set_caption("Weather Conditions")\
.background_gradient(axis=None, vmin=1, vmax=5, cmap='BuPu',subset=['Tokyo'])\
.format(rain_condition)\
.format_index(change_index)
# Out:
# <style type="text/css">
# #T_2f99d_row0_col0 {
#   background-color: #bacfe4;
#   color: #000000;
# }
# #T_2f99d_row1_col0 {
#   background-color: #cedfec;
#   color: #000000;
# }
# #T_2f99d_row2_col0 {
#   background-color: #8c69b0;
#   color: #f1f1f1;
# }
# #T_2f99d_row3_col0 {
#   background-color: #8c80bb;
#   color: #f1f1f1;
# }
# #T_2f99d_row4_col0 {
#   background-color: #c1d4e7;
#   color: #000000;
# }
# #T_2f99d_row5_col0 {
#   background-color: #a4c0dc;
#   color: #000000;
# }
# #T_2f99d_row6_col0 {
#   background-color: #8c71b4;
#   color: #f1f1f1;
# }
# #T_2f99d_row7_col0 {
#   background-color: #dce9f2;
#   color: #000000;
# }
# #T_2f99d_row8_col0 {
#   background-color: #852d90;
#   color: #f1f1f1;
# }
# #T_2f99d_row9_col0 {
#   background-color: #92a4cd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2f99d">
#   <caption>Weather Conditions</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f99d_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_2f99d_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f99d_level0_row0" class="row_heading level0 row0" >2021年01月01日</th>
#       <td id="T_2f99d_row0_col0" class="data row0 col0" >有雨</td>
#       <td id="T_2f99d_row0_col1" class="data row0 col1" >大雨</td>
#     </tr>
#     <tr>
#       <th id="T_2f99d_level0_row1" class="row_heading level0 row1" >2021年01月02日</th>
#       <td id="T_2f99d_row1_col0" class="data row1 col0" >有雨</td>
#       <td id="T_2f99d_row1_col1" class="data row1 col1" >有雨</td>
#     </tr>
#     <tr>
#       <th id="T_2f99d_level0_row2" class="row_heading level0 row2" >2021年01月03日</th>
#       <td id="T_2f99d_row2_col0" class="data row2 col0" >大雨</td>
#       <td id="T_2f99d_row2_col1" class="data row2 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_2f99d_level0_row3" class="row_heading level0 row3" >2021年01月04日</th>
#       <td id="T_2f99d_row3_col0" class="data row3 col0" >大雨</td>
#       <td id="T_2f99d_row3_col1" class="data row3 col1" >有雨</td>
#     </tr>
#     <tr>
#       <th id="T_2f99d_level0_row4" class="row_heading level0 row4" >2021年01月05日</th>
#       <td id="T_2f99d_row4_col0" class="data row4 col0" >有雨</td>
#       <td id="T_2f99d_row4_col1" class="data row4 col1" >有雨</td>
#     </tr>
#     <tr>
#       <th id="T_2f99d_level0_row5" class="row_heading level0 row5" >2021年01月06日</th>
#       <td id="T_2f99d_row5_col0" class="data row5 col0" >有雨</td>
#       <td id="T_2f99d_row5_col1" class="data row5 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_2f99d_level0_row6" class="row_heading level0 row6" >2021年01月07日</th>
#       <td id="T_2f99d_row6_col0" class="data row6 col0" >大雨</td>
#       <td id="T_2f99d_row6_col1" class="data row6 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_2f99d_level0_row7" class="row_heading level0 row7" >2021年01月08日</th>
#       <td id="T_2f99d_row7_col0" class="data row7 col0" >乾燥</td>
#       <td id="T_2f99d_row7_col1" class="data row7 col1" >有雨</td>
#     </tr>
#     <tr>
#       <th id="T_2f99d_level0_row8" class="row_heading level0 row8" >2021年01月09日</th>
#       <td id="T_2f99d_row8_col0" class="data row8 col0" >大雨</td>
#       <td id="T_2f99d_row8_col1" class="data row8 col1" >大雨</td>
#     </tr>
#     <tr>
#       <th id="T_2f99d_level0_row9" class="row_heading level0 row9" >2021年01月10日</th>
#       <td id="T_2f99d_row9_col0" class="data row9 col0" >大雨</td>
#       <td id="T_2f99d_row9_col1" class="data row9 col1" >大雨</td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np
np.random.seed(0)
df2 = pd.DataFrame(np.random.randn(10,4),columns=['A','B','C','D'])
display(df2.style)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f7a5f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7a5f_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_f7a5f_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_f7a5f_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_f7a5f_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7a5f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f7a5f_row0_col0" class="data row0 col0" >1.764052</td>
#       <td id="T_f7a5f_row0_col1" class="data row0 col1" >0.400157</td>
#       <td id="T_f7a5f_row0_col2" class="data row0 col2" >0.978738</td>
#       <td id="T_f7a5f_row0_col3" class="data row0 col3" >2.240893</td>
#     </tr>
#     <tr>
#       <th id="T_f7a5f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f7a5f_row1_col0" class="data row1 col0" >1.867558</td>
#       <td id="T_f7a5f_row1_col1" class="data row1 col1" >-0.977278</td>
#       <td id="T_f7a5f_row1_col2" class="data row1 col2" >0.950088</td>
#       <td id="T_f7a5f_row1_col3" class="data row1 col3" >-0.151357</td>
#     </tr>
#     <tr>
#       <th id="T_f7a5f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f7a5f_row2_col0" class="data row2 col0" >-0.103219</td>
#       <td id="T_f7a5f_row2_col1" class="data row2 col1" >0.410599</td>
#       <td id="T_f7a5f_row2_col2" class="data row2 col2" >0.144044</td>
#       <td id="T_f7a5f_row2_col3" class="data row2 col3" >1.454274</td>
#     </tr>
#     <tr>
#       <th id="T_f7a5f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f7a5f_row3_col0" class="data row3 col0" >0.761038</td>
#       <td id="T_f7a5f_row3_col1" class="data row3 col1" >0.121675</td>
#       <td id="T_f7a5f_row3_col2" class="data row3 col2" >0.443863</td>
#       <td id="T_f7a5f_row3_col3" class="data row3 col3" >0.333674</td>
#     </tr>
#     <tr>
#       <th id="T_f7a5f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f7a5f_row4_col0" class="data row4 col0" >1.494079</td>
#       <td id="T_f7a5f_row4_col1" class="data row4 col1" >-0.205158</td>
#       <td id="T_f7a5f_row4_col2" class="data row4 col2" >0.313068</td>
#       <td id="T_f7a5f_row4_col3" class="data row4 col3" >-0.854096</td>
#     </tr>
#     <tr>
#       <th id="T_f7a5f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f7a5f_row5_col0" class="data row5 col0" >-2.552990</td>
#       <td id="T_f7a5f_row5_col1" class="data row5 col1" >0.653619</td>
#       <td id="T_f7a5f_row5_col2" class="data row5 col2" >0.864436</td>
#       <td id="T_f7a5f_row5_col3" class="data row5 col3" >-0.742165</td>
#     </tr>
#     <tr>
#       <th id="T_f7a5f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f7a5f_row6_col0" class="data row6 col0" >2.269755</td>
#       <td id="T_f7a5f_row6_col1" class="data row6 col1" >-1.454366</td>
#       <td id="T_f7a5f_row6_col2" class="data row6 col2" >0.045759</td>
#       <td id="T_f7a5f_row6_col3" class="data row6 col3" >-0.187184</td>
#     </tr>
#     <tr>
#       <th id="T_f7a5f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f7a5f_row7_col0" class="data row7 col0" >1.532779</td>
#       <td id="T_f7a5f_row7_col1" class="data row7 col1" >1.469359</td>
#       <td id="T_f7a5f_row7_col2" class="data row7 col2" >0.154947</td>
#       <td id="T_f7a5f_row7_col3" class="data row7 col3" >0.378163</td>
#     </tr>
#     <tr>
#       <th id="T_f7a5f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f7a5f_row8_col0" class="data row8 col0" >-0.887786</td>
#       <td id="T_f7a5f_row8_col1" class="data row8 col1" >-1.980796</td>
#       <td id="T_f7a5f_row8_col2" class="data row8 col2" >-0.347912</td>
#       <td id="T_f7a5f_row8_col3" class="data row8 col3" >0.156349</td>
#     </tr>
#     <tr>
#       <th id="T_f7a5f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f7a5f_row9_col0" class="data row9 col0" >1.230291</td>
#       <td id="T_f7a5f_row9_col1" class="data row9 col1" >1.202380</td>
#       <td id="T_f7a5f_row9_col2" class="data row9 col2" >-0.387327</td>
#       <td id="T_f7a5f_row9_col3" class="data row9 col3" >-0.302303</td>
#     </tr>
#   </tbody>
# </table>

# %%
def style_negative(v):
    return 'color:red'
df2.style.applymap(style_negative)
# Out:
# C:\Users\Jessi\AppData\Local\Temp\ipykernel_32720\964041340.py:3: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   df2.style.applymap(style_negative)
# <style type="text/css">
# #T_61c0a_row0_col0, #T_61c0a_row0_col1, #T_61c0a_row0_col2, #T_61c0a_row0_col3, #T_61c0a_row1_col0, #T_61c0a_row1_col1, #T_61c0a_row1_col2, #T_61c0a_row1_col3, #T_61c0a_row2_col0, #T_61c0a_row2_col1, #T_61c0a_row2_col2, #T_61c0a_row2_col3, #T_61c0a_row3_col0, #T_61c0a_row3_col1, #T_61c0a_row3_col2, #T_61c0a_row3_col3, #T_61c0a_row4_col0, #T_61c0a_row4_col1, #T_61c0a_row4_col2, #T_61c0a_row4_col3, #T_61c0a_row5_col0, #T_61c0a_row5_col1, #T_61c0a_row5_col2, #T_61c0a_row5_col3, #T_61c0a_row6_col0, #T_61c0a_row6_col1, #T_61c0a_row6_col2, #T_61c0a_row6_col3, #T_61c0a_row7_col0, #T_61c0a_row7_col1, #T_61c0a_row7_col2, #T_61c0a_row7_col3, #T_61c0a_row8_col0, #T_61c0a_row8_col1, #T_61c0a_row8_col2, #T_61c0a_row8_col3, #T_61c0a_row9_col0, #T_61c0a_row9_col1, #T_61c0a_row9_col2, #T_61c0a_row9_col3 {
#   color: red;
# }
# </style>
# <table id="T_61c0a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61c0a_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_61c0a_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_61c0a_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_61c0a_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61c0a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61c0a_row0_col0" class="data row0 col0" >1.764052</td>
#       <td id="T_61c0a_row0_col1" class="data row0 col1" >0.400157</td>
#       <td id="T_61c0a_row0_col2" class="data row0 col2" >0.978738</td>
#       <td id="T_61c0a_row0_col3" class="data row0 col3" >2.240893</td>
#     </tr>
#     <tr>
#       <th id="T_61c0a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_61c0a_row1_col0" class="data row1 col0" >1.867558</td>
#       <td id="T_61c0a_row1_col1" class="data row1 col1" >-0.977278</td>
#       <td id="T_61c0a_row1_col2" class="data row1 col2" >0.950088</td>
#       <td id="T_61c0a_row1_col3" class="data row1 col3" >-0.151357</td>
#     </tr>
#     <tr>
#       <th id="T_61c0a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_61c0a_row2_col0" class="data row2 col0" >-0.103219</td>
#       <td id="T_61c0a_row2_col1" class="data row2 col1" >0.410599</td>
#       <td id="T_61c0a_row2_col2" class="data row2 col2" >0.144044</td>
#       <td id="T_61c0a_row2_col3" class="data row2 col3" >1.454274</td>
#     </tr>
#     <tr>
#       <th id="T_61c0a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_61c0a_row3_col0" class="data row3 col0" >0.761038</td>
#       <td id="T_61c0a_row3_col1" class="data row3 col1" >0.121675</td>
#       <td id="T_61c0a_row3_col2" class="data row3 col2" >0.443863</td>
#       <td id="T_61c0a_row3_col3" class="data row3 col3" >0.333674</td>
#     </tr>
#     <tr>
#       <th id="T_61c0a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_61c0a_row4_col0" class="data row4 col0" >1.494079</td>
#       <td id="T_61c0a_row4_col1" class="data row4 col1" >-0.205158</td>
#       <td id="T_61c0a_row4_col2" class="data row4 col2" >0.313068</td>
#       <td id="T_61c0a_row4_col3" class="data row4 col3" >-0.854096</td>
#     </tr>
#     <tr>
#       <th id="T_61c0a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_61c0a_row5_col0" class="data row5 col0" >-2.552990</td>
#       <td id="T_61c0a_row5_col1" class="data row5 col1" >0.653619</td>
#       <td id="T_61c0a_row5_col2" class="data row5 col2" >0.864436</td>
#       <td id="T_61c0a_row5_col3" class="data row5 col3" >-0.742165</td>
#     </tr>
#     <tr>
#       <th id="T_61c0a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_61c0a_row6_col0" class="data row6 col0" >2.269755</td>
#       <td id="T_61c0a_row6_col1" class="data row6 col1" >-1.454366</td>
#       <td id="T_61c0a_row6_col2" class="data row6 col2" >0.045759</td>
#       <td id="T_61c0a_row6_col3" class="data row6 col3" >-0.187184</td>
#     </tr>
#     <tr>
#       <th id="T_61c0a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_61c0a_row7_col0" class="data row7 col0" >1.532779</td>
#       <td id="T_61c0a_row7_col1" class="data row7 col1" >1.469359</td>
#       <td id="T_61c0a_row7_col2" class="data row7 col2" >0.154947</td>
#       <td id="T_61c0a_row7_col3" class="data row7 col3" >0.378163</td>
#     </tr>
#     <tr>
#       <th id="T_61c0a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_61c0a_row8_col0" class="data row8 col0" >-0.887786</td>
#       <td id="T_61c0a_row8_col1" class="data row8 col1" >-1.980796</td>
#       <td id="T_61c0a_row8_col2" class="data row8 col2" >-0.347912</td>
#       <td id="T_61c0a_row8_col3" class="data row8 col3" >0.156349</td>
#     </tr>
#     <tr>
#       <th id="T_61c0a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_61c0a_row9_col0" class="data row9 col0" >1.230291</td>
#       <td id="T_61c0a_row9_col1" class="data row9 col1" >1.202380</td>
#       <td id="T_61c0a_row9_col2" class="data row9 col2" >-0.387327</td>
#       <td id="T_61c0a_row9_col3" class="data row9 col3" >-0.302303</td>
#     </tr>
#   </tbody>
# </table>
