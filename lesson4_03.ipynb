# %%
import csv
from pprint import pprint
with open(file='ABCCC.csv', encoding='utf-8') as file:
    reader = csv.DictReader(file)  
    drug = list(reader)

pprint(drug)
# Out:
# [{'上年度預算數百分比': '100',
#   '上年度預算數金額': '119,026,042',
#   '前年度決算數百分比': '100',
#   '前年度決算數金額': '118,804,725',
#   '本年度與上年度比較增加率': '4.29',
#   '本年度與上年度比較金額': '5,100,556',
#   '本年度預算數百分比': '100',
#   '本年度預算數金額': '124,126,598',
#   '\ufeff項目': '\u3000（一）經常門歲入'},
#  {'上年度預算數百分比': '44.9',
#   '上年度預算數金額': '53,441,821',
#   '前年度決算數百分比': '45.9',
#   '前年度決算數金額': '54,528,334',
#   '本年度與上年度比較增加率': '0.71',
#   '本年度與上年度比較金額': '382,082',
#   '本年度預算數百分比': '43.36',
#   '本年度預算數金額': '53,823,903',
#   '\ufeff項目': '\u3000\u30001.直接稅收入'},
#  {'上年度預算數百分比': '16.41',
#   '上年度預算數金額': '19,531,146',
#   '前年度決算數百分比': '17.03',
#   '前年度決算數金額': '20,229,648',
#   '本年度與上年度比較增加率': '1.13',
#   '本年度與上年度比較金額': '219,892',
#   '本年度預算數百分比': '15.91',
#   '本年度預算數金額': '19,751,038',
#   '\ufeff項目': '\u3000\u30002.間接稅收入'},
#  {'上年度預算數百分比': '38.69',
#   '上年度預算數金額': '46,053,075',
#   '前年度決算數百分比': '37.07',
#   '前年度決算數金額': '44,046,743',
#   '本年度與上年度比較增加率': '9.77',
#   '本年度與上年度比較金額': '4,498,582',
#   '本年度預算數百分比': '40.73',
#   '本年度預算數金額': '50,551,657',
#   '\ufeff項目': '\u3000\u30003.賦稅外收入'},
#  {'上年度預算數百分比': '100',
#   '上年度預算數金額': '109,002,220',
#   '前年度決算數百分比': '100',
#   '前年度決算數金額': '103,373,949',
#   '本年度與上年度比較增加率': '2.81',
#   '本年度與上年度比較金額': '3,063,304',
#   '本年度預算數百分比': '100',
#   '本年度預算數金額': '112,065,524',
#   '\ufeff項目': '\u3000（二）經常門歲出'},
#  {'上年度預算數百分比': '97.68',
#   '上年度預算數金額': '106,474,976',
#   '前年度決算數百分比': '98.72',
#   '前年度決算數金額': '102,052,662',
#   '本年度與上年度比較增加率': '2.87',
#   '本年度與上年度比較金額': '3,058,889',
#   '本年度預算數百分比': '97.74',
#   '本年度預算數金額': '109,533,865',
#   '\ufeff項目': '\u3000\u30001.一般經常支出'},
#  {'上年度預算數百分比': '2.06',
#   '上年度預算數金額': '2,245,311',
#   '前年度決算數百分比': '1.24',
#   '前年度決算數金額': '1,280,481',
#   '本年度與上年度比較增加率': '-',
#   '本年度與上年度比較金額': '-',
#   '本年度預算數百分比': '2',
#   '本年度預算數金額': '2,245,311',
#   '\ufeff項目': '\u3000\u30002.債務利息及事務支出'},
#  {'上年度預算數百分比': '0.26',
#   '上年度預算數金額': '281,933',
#   '前年度決算數百分比': '0.04',
#   '前年度決算數金額': '40,806',
#   '本年度與上年度比較增加率': '1.57',
#   '本年度與上年度比較金額': '4,415',
#   '本年度預算數百分比': '0.26',
#   '本年度預算數金額': '286,348',
#   '\ufeff項目': '\u3000\u30003.預備金'},
#  {'上年度預算數百分比': '100',
#   '上年度預算數金額': '10,023,822',
#   '前年度決算數百分比': '100',
#   '前年度決算數金額': '15,430,776',
#   '本年度與上年度比較增加率': '20.32',
#   '本年度與上年度比較金額': '2,037,252',
#   '本年度預算數百分比': '100',
#   '本年度預算數金額': '12,061,074',
#   '\ufeff項目': '\u3000（三）經常門賸餘'},
#  {'上年度預算數百分比': '100',
#   '上年度預算數金額': '3,236,758',
#   '前年度決算數百分比': '100',
#   '前年度決算數金額': '4,251,540',
#   '本年度與上年度比較增加率': '-12.97',
#   '本年度與上年度比較金額': '-419,791',
#   '本年度預算數百分比': '100',
#   '本年度預算數金額': '2,816,967',
#   '\ufeff項目': '\u3000（一）資本門歲入'},
#  {'上年度預算數百分比': '100',
#   '上年度預算數金額': '3,236,758',
#   '前年度決算數百分比': '100',
#   '前年度決算數金額': '4,251,540',
#   '本年度與上年度比較增加率': '-12.97',
#   '本年度與上年度比較金額': '-419,791',
#   '本年度預算數百分比': '100',
#   '本年度預算數金額': '2,816,967',
#   '\ufeff項目': '\u3000\u30001.減少資產'},
#  {'上年度預算數百分比': '-',
#   '上年度預算數金額': '-',
#   '前年度決算數百分比': '-',
#   '前年度決算數金額': '-',
#   '本年度與上年度比較增加率': '-',
#   '本年度與上年度比較金額': '-',
#   '本年度預算數百分比': '-',
#   '本年度預算數金額': '-',
#   '\ufeff項目': '\u3000\u30002.收回投資'},
#  {'上年度預算數百分比': '100',
#   '上年度預算數金額': '20,163,182',
#   '前年度決算數百分比': '100',
#   '前年度決算數金額': '18,383,865',
#   '本年度與上年度比較增加率': '6.25',
#   '本年度與上年度比較金額': '1,260,873',
#   '本年度預算數百分比': '100',
#   '本年度預算數金額': '21,424,055',
#   '\ufeff項目': '\u3000（二）資本門歲出'},
#  {'上年度預算數百分比': '92.24',
#   '上年度預算數金額': '18,597,985',
#   '前年度決算數百分比': '90.41',
#   '前年度決算數金額': '16,620,619',
#   '本年度與上年度比較增加率': '6.08',
#   '本年度與上年度比較金額': '1,130,771',
#   '本年度預算數百分比': '92.09',
#   '本年度預算數金額': '19,728,756',
#   '\ufeff項目': '\u3000\u30001.增置或擴充改良資產'},
#  {'上年度預算數百分比': '0.67',
#   '上年度預算數金額': '134,830',
#   '前年度決算數百分比': '5.24',
#   '前年度決算數金額': '962,824',
#   '本年度與上年度比較增加率': '67.79',
#   '本年度與上年度比較金額': '91,402',
#   '本年度預算數百分比': '1.05',
#   '本年度預算數金額': '226,232',
#   '\ufeff項目': '\u3000\u30002.增加投資'},
#  {'上年度預算數百分比': '7.09',
#   '上年度預算數金額': '1,430,367',
#   '前年度決算數百分比': '4.35',
#   '前年度決算數金額': '800,422',
#   '本年度與上年度比較增加率': '2.71',
#   '本年度與上年度比較金額': '38,700',
#   '本年度預算數百分比': '6.86',
#   '本年度預算數金額': '1,469,067',
#   '\ufeff項目': '\u3000\u30003.預備金'},
#  {'上年度預算數百分比': '100',
#   '上年度預算數金額': '-16,926,424',
#   '前年度決算數百分比': '100',
#   '前年度決算數金額': '-14,132,325',
#   '本年度與上年度比較增加率': '9.93',
#   '本年度與上年度比較金額': '-1,680,664',
#   '本年度預算數百分比': '100',
#   '本年度預算數金額': '-18,607,088',
#   '\ufeff項目': '\u3000（三）資本門差短'},
#  {'上年度預算數百分比': '100',
#   '上年度預算數金額': '-6,902,602',
#   '前年度決算數百分比': '100',
#   '前年度決算數金額': '1,298,451',
#   '本年度與上年度比較增加率': '-5.17',
#   '本年度與上年度比較金額': '356,588',
#   '本年度預算數百分比': '100',
#   '本年度預算數金額': '-6,546,014',
#   '\ufeff項目': '三、歲入歲出餘絀'}]

# %%
import requests

url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'

try:
    response = requests.get(url)
    response.raise_for_status()  # 檢查HTTP狀態碼，確保請求成功

    data = response.json()  # 將JSON格式的資料轉換為Python字典

    # 在這裡你可以對data做任何處理，例如儲存到檔案或分析資料
    # 以下是一個簡單的範例，將資料儲存到youbike_data.json檔案中
    with open('youbike_data.json', 'w', encoding='utf-8') as f:
        import json
        json.dump(data, f, ensure_ascii=False, indent=4)

    print('YouBike即時資訊下載完成！')

except requests.exceptions.RequestException as e:
    print(f'下載YouBike即時資訊時發生錯誤：{e}')
except json.JSONDecodeError as e:
    print(f'解析JSON資料時發生錯誤：{e}')
# Out:
# YouBike即時資訊下載完成！
