# %%
import pandas as pd
df = pd.read_csv('student.csv',index_col=0)  # 利用index_col=0 來指定第一個欄位作為索引
df
# Out:
#      chinese  english  math  geo  explore
# 魏秋萍       88       97    50   96       75
# 鄭孟芳       69       98    61   82       83
# 李彥伸       77       64    76   65       50
# 李湘婷       88       89    78   60       64
# 劉佳佩       80       81    65   59       86
# 簡國瑋       53       84    54   76       66
# 童建霖       69       95   100   56       70
# 陳筱涵       76       83    78  100       98
# 高智超       68       64    83   70       60
# 林益妏       72       52    79   80       61
# 黃柏宇       70       75    81   60       55
# 蔡至剛       83       69    57   86       76
# 林志成       57       53    71   93       82
# 羅幸娥       90       59    95   57       71
# 王梅劭       73       91    68   50       96
# 吳志宣       63      100    76   89       96
# 游倫城       83       56    57   56       53
# 周家銘       64       97    66   52       51
# 陳淑萍       98       81    79   68       83
# 錢佩豪       74       55    64   81       60
# 陳信宏       70       77    98   79       83
# ...
